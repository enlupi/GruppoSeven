# %% [markdown]
# # Respiratory rate estimation
#
# ### Description
#
# Seismocardiography([SCG](https://www.ncbi.nlm.nih.gov/pubmed/24111357) is a very promising technique to measure Heart Rate (HR) and Respiratory Rate (RR) with the detector positioned above sternum. It is generally based on accelerometer and gyroscope readings or a combination of them.
# Ballistocardiography([BCG](https://en.wikipedia.org/wiki/Ballistocardiography)) is an another technique to estimate heart and respiratory rate with combination of both accelerometer and gyroscope. It is an indirect evaluation of HR and RR since the contact between the device and the body of the subject is not required (e.g., accelerometer platform mounted under the slats of the bed).
# MuSe(Multi-Sensor miniaturized, low-power, wireless [IMU](https://en.wikipedia.org/wiki/Inertial_measurement_unit)) is an Inertial Measurement Unit (IMU) provide by (221e)[https://www.221e.com]. In the context of this project, It allows to record the inertial data necessary for the estimation of SCG and BCG.
# The goal of this assignment is to estimate the respiratory rate of an healthy subject, given linear acceleration and angular velocity measurements recorded by using the aforementioned MuSe platform. The study must be performed on two datasets: the first is the compulsory one (center_sternum.txt) while the second is left at the discretion of the group, among those made available for the assignment.
# N.B: Remember that normal beat is around 40-100 bpm.
#
# [Actigraphy](https://en.wikipedia.org/wiki/Actigraphy) is a non-invasive method of monitoring human rest/activity cycles. Data will be provided from sensors gathering data on humans during their day/night activities
#
# ### Datasets
#
# The data is provided in .txt file. During this study two healthy subjects were involved with their informed consent. The first dataset was recorded on one subject, while all the other datasets were recorded on the second subject.
#
# This is the first mandatory file:
# * center_sternum.txt: MuSe placed on the center of the sternum. The subject was lying supine on his left and right side, respectively.
#
# Choose one of the following files in order to complete the task.
# 1. 1_Stave_supine_static.txt: Sensor placed on a bed stave, under the mattress at the level of the chest. The subject was lying supine on his left and right side.
# 2. 2_Mattress_supine.txt: Sensor placed on the mattress, near one corner but not under the pillow. The subject laid in the same position as above.
# 3. 3_Subject_sitting_chair.txt: Sensor placed on the desk: the subject, sitting on a chair, leaned forearms and hands on the desk.
# 4. 4_Chest_sweater.txt: Sensor placed on the subject chest directly on a sweater.
# 5. 5_Under_chair.txt: Subject sitting on a chair, sensor placed under the seat of the chair.
#
# All .txt files give 16 columns index, in particular:
# * Log Freq stands for the acquisition in Hz (i.e., sampling interval is constant).
# * AccX, AccY, AccZ are the measured magnitude of linear acceleration along each axis.
# * GyroX, GyroY, GyroZ are the measured magnitude of angular velocity along each axis.
# * MagnX, MagnY, MagnZ are the measured magnitude of magnetic field along each axis.
# * qw, qi, qj, qk are the quaternion components, representing the spatial orientation of the Muse
# system.
#
# Each dataset includes, in addition to the data, one file containing the adopted configuration of the MuSe(README1.txt for the first measurement, and in README_5.txt for the other measurement).
#
# ### Assignments
#
# Data preparation:
#
# 1.1. Load the txt file and select only the columns you are interesting in, in order to do a complete data analysis (e.g. Log Freq, AccX, ... )
#
# 1.2. Plot selected data in function of time and choose a properly time window over which to perform the analysis. Pay attention on time rappresentation and the measurament unit.
#
# 1.3. In order to make an appropiate work, decide if take care about some particular axis or some combination of them as well as derived features for the next step of the task. Motivate your choice.
#
# Time and frequency analysis:
#
# 2.1. Statistical analysis: provide a statistical description of the chosen dataset. Statistical
# descriptors includes for example mean, median, variance, standard deviation, 25th and 75th percentiles, and correlation coefficients. Investigate what could be the most interesting descriptors for this type of data, motivating the choices.
#
# 2.2. Fourier Analysis: Perform a frequency analysis of the data. Look at the spectrum and explain what you see. Use this step in order to properly design the filters in the following step.
#
# Filter:
#
# Implement your own filter, trying to extrapolate respiratory rate signal. Hint:
#
# (a) Directly from Fourier Analysis, antitrasform data looking for the most interesting frequency band.
#
# (b) Choose the appropriate Lowpass/Bandpass/Highpass filter.
#
# (c) Wavelet trasform (a powerfull instrument that make a time and frequency analysis of signal). (d) Find another method by yourselves.
#
# Motivate your choice.
#
# Metrics:
#
# 4.1. Respiratory Rate Per Minute(RPM): extrapolate RPM, make an histogram of the result. Does it follow a partiular distribution?
#
# 4.2. Respiratory Rate Variability(RRV): extrapolate RRV, explain why this parameter is important, and plot the results.
#
# (OPTIONAL) Algorithm: Elaborate a simple algorithm to extrapolate respiratory rate even when filter failed (e.g. look at particular threshold...).
#
# Conclusion:
#  Summarise the obtained results, in particular making a comparison between the two files analysed. Highlight limitation and critical issues encountered during the work, motivating the most relevant contribution given by your solution.
#
# N.B: Indicate the contribution, to achieving the result, of each member of the group.
#
#
#
# ### Contacts
#
# * Marco Zanetti <marco.zanetti@unipd.it>
# * Marco Signorelli <signo@221e.com>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import fftpack
from scipy import fft


data = pd.read_csv('center_sternum.txt',sep='\t')
df = pd.DataFrame(data[2618:12404])
print(df)
#for i in range(16506):
 #   print(df['Log Mode'][i], df['Log Freq'][i], df['Timestamp'][i])
  #  print(df['AccX'][i], df['AccY'][i], df['AccZ'][i])
#data = np.loadtxt('center_sternum.txt')
time, counts = np.unique(df['Timestamp'], return_counts=True)
for i,j in zip(time,counts):
    print(i,j)
time = np.arange(9786)
time=time/200
dt=1/200
plt.plot(time, df['AccX'], label='AccX')
plt.xlabel('Time')
plt.ylabel('Acceleration')
plt.legend()
plt.show()
plt.plot(time, df['AccY'], label='AccY')
plt.xlabel('Time')
plt.ylabel('Acceleration')
plt.legend()
plt.show()
plt.plot(time, df['AccZ'], label='AccZ')
plt.xlabel('Time')
plt.ylabel('Acceleration')
plt.legend()
plt.show()
plt.plot(time, df['GyroX'], label='GyroX')
plt.xlabel('Time')
plt.ylabel('Angular velocity')
plt.legend()
plt.show()
plt.plot(time, df['GyroY'], label='GyroY')
plt.xlabel('Time')
plt.ylabel('Angular velocity')
plt.legend()
plt.show()
plt.plot(time, df['GyroZ'], label='GyroZ')
plt.xlabel('Time')
plt.ylabel('Angular velocity')
plt.legend()
plt.show()
plt.plot(time, df['MagnX'], label='MagX')
plt.xlabel('Time')
plt.ylabel('Magnetic magnitude X')
plt.legend()
plt.show()
plt.plot(time, df['MagnY'], label='MagY')
plt.xlabel('Time')
plt.ylabel('Magnetic magnitude Y')
plt.legend()
plt.show()
plt.plot(time, df['MagnZ'], label='MagZ')
plt.xlabel('Time')
plt.ylabel('Magnetic magnitude Z')
plt.legend()
plt.show()
plt.plot(time, df['qi'], label='qi')
plt.xlabel('Time')
plt.ylabel('qi')
plt.legend()
plt.show()
plt.plot(time, df['qj'], label='qj')
plt.xlabel('Time')
plt.ylabel('qj')
plt.legend()
plt.show()
plt.plot(time, df['qk'], label='qk')
plt.xlabel('Time')
plt.ylabel('qk')
plt.legend()
plt.show()
plt.plot(time, df['qw'], label='qw')
plt.xlabel('Time')
plt.ylabel('qw')
plt.legend()
plt.show()




#statistical analysis

print('Mean of accX', df['AccX'].mean())
print('Mean of accY', df['AccY'].mean())
print('Mean of accZ', df['AccZ'].mean())
print('Mean of angX', df['GyroX'].mean())
print('Mean of angY', df['GyroY'].mean())
print('Mean of angZ', df['GyroZ'].mean())
print('Median of accX', df['AccX'].median())
print('Median of accY', df['AccY'].median())
print('Median of accZ', df['AccZ'].median())
print('Median of angX', df['GyroX'].median())
print('Median of angY', df['GyroY'].median())
print('Median of angZ', df['GyroZ'].median())
print('Std of accX', df['AccX'].std())
print('Std of accY', df['AccY'].std())
print('Std of accZ', df['AccZ'].std())
print('Std of angX', df['GyroX'].std())
print('Std of angY', df['GyroY'].std())
print('Std of angZ', df['GyroZ'].std())
print('Variance of accX', df['AccX'].var())
print('Variance of accY', df['AccY'].var())
print('Variance of accZ', df['AccZ'].var())
print('Variance of angX', df['GyroX'].var())
print('Variance of angY', df['GyroY'].var())
print('Variance of angZ', df['GyroZ'].var())
print('75 percentiles of AccX', np.percentile(df['AccX'],75))
print('75 percentiles of AccY', np.percentile(df['AccY'],75))
print('75 percentiles of AccZ', np.percentile(df['AccZ'],75))
print('75 percentiles of GyroX', np.percentile(df['GyroX'],75))
print('75 percentiles of GyroY', np.percentile(df['GyroY'],75))
print('75 percentiles of GyroZ', np.percentile(df['GyroZ'],75))
print('25 percentiles of AccX', np.percentile(df['AccX'],25))
print('25 percentiles of AccY', np.percentile(df['AccY'],25))
print('25 percentiles of AccZ', np.percentile(df['AccZ'],25))
print('25 percentiles of GyroX', np.percentile(df['GyroX'],25))
print('25 percentiles of GyroY', np.percentile(df['GyroY'],25))
print('25 percentiles of GyroZ', np.percentile(df['GyroZ'],25))
print('coef AccX-AccY', np.corrcoef(df['AccX'],y=df['AccY']))
print('coef AccX-AccZ', np.corrcoef(df['AccX'],y=df['AccZ']))
print('coef AccX-GyroX', np.corrcoef(df['AccX'],y=df['GyroX']))
print('coef AccX-GyroY', np.corrcoef(df['AccX'],y=df['GyroY']))
print('coef AccX-GyroZ', np.corrcoef(df['AccX'],y=df['GyroZ']))
print('coef AccY-AccZ', np.corrcoef(df['AccY'],y=df['AccZ']))
print('coef AccY-GyroX', np.corrcoef(df['AccY'],y=df['GyroX']))
print('coef AccY-GyroY', np.corrcoef(df['AccY'],y=df['GyroY']))
print('coef AccY-GyroZ', np.corrcoef(df['AccY'],y=df['GyroZ']))
print('coef AccZ-GyroX', np.corrcoef(df['AccZ'],y=df['GyroX']))
print('coef AccZ-GyroY', np.corrcoef(df['AccZ'],y=df['GyroY']))
print('coef AccZ-GyroZ', np.corrcoef(df['AccZ'],y=df['GyroZ']))
print('coef GyroX-GyroY', np.corrcoef(df['GyroX'],y=df['GyroY']))
print('coef GyroX-GyroZ', np.corrcoef(df['GyroX'],y=df['GyroZ']))
print('coef GyroY-GyroZ', np.corrcoef(df['GyroY'],y=df['GyroZ']))
print('coef AccX-magnX', np.corrcoef(df['AccX'],y=df['MagnX']))
print('coef AccX-magnY', np.corrcoef(df['AccX'],y=df['MagnY']))
print('coef AccX-magnZ', np.corrcoef(df['AccX'],y=df['MagnZ']))
print('coef AccY-magnX', np.corrcoef(df['AccY'],y=df['MagnX']))
print('coef AccY-magnY', np.corrcoef(df['AccY'],y=df['MagnY']))
print('coef AccY-magnZ', np.corrcoef(df['AccY'],y=df['MagnZ']))
print('coef AccZ-magnX', np.corrcoef(df['AccZ'],y=df['MagnX']))
print('coef AccZ-magnY', np.corrcoef(df['AccZ'],y=df['MagnY']))
print('coef AccZ-magnZ', np.corrcoef(df['AccZ'],y=df['MagnZ']))
print('coef GyroX-magnX', np.corrcoef(df['GyroX'],y=df['MagnX']))
print('coef GyroX-magnY', np.corrcoef(df['GyroX'],y=df['MagnY']))
print('coef GyroX-magnZ', np.corrcoef(df['GyroX'],y=df['MagnZ']))
print('coef GyroY-magnX', np.corrcoef(df['GyroY'],y=df['MagnY']))
print('coef GyroY-magnY', np.corrcoef(df['GyroY'],y=df['MagnZ']))
print('coef GyroY-magnZ', np.corrcoef(df['GyroY'],y=df['MagnZ']))
print('coef GyroZ-magnX', np.corrcoef(df['GyroZ'],y=df['MagnY']))
print('coef GyroZ-magnY', np.corrcoef(df['GyroZ'],y=df['MagnZ']))
print('coef GyroZ-magnZ', np.corrcoef(df['GyroZ'],y=df['MagnZ']))
print('coef AccX-qi', np.corrcoef(df['AccX'],y=df['qi']))
print('coef AccX-qj', np.corrcoef(df['AccX'],y=df['qj']))
print('coef AccX-qk', np.corrcoef(df['AccX'],y=df['qk']))
print('coef AccY-qi', np.corrcoef(df['AccY'],y=df['qi']))
print('coef AccY-qj', np.corrcoef(df['AccY'],y=df['qj']))
print('coef AccY-qk', np.corrcoef(df['AccY'],y=df['qk']))
print('coef AccZ-qi', np.corrcoef(df['AccZ'],y=df['qi']))
print('coef AccZ-qj', np.corrcoef(df['AccZ'],y=df['qj']))
print('coef AccZ-qk', np.corrcoef(df['AccZ'],y=df['qk']))
print('coef AccX-qw', np.corrcoef(df['AccX'],y=df['qw']))
print('coef AccY-qw', np.corrcoef(df['AccY'],y=df['qw']))
print('coef AccZ-qw', np.corrcoef(df['AccZ'],y=df['qw']))
print('coef GyroX-qi', np.corrcoef(df['GyroX'],y=df['qi']))
print('coef GyroX-qj', np.corrcoef(df['GyroX'],y=df['qj']))
print('coef GyroX-qk', np.corrcoef(df['GyroX'],y=df['qk']))
print('coef GyroY-qi', np.corrcoef(df['GyroY'],y=df['qi']))
print('coef GyroY-qj', np.corrcoef(df['GyroY'],y=df['qj']))
print('coef GyroY-qk', np.corrcoef(df['GyroY'],y=df['qk']))
print('coef GyroZ-qi', np.corrcoef(df['GyroZ'],y=df['qi']))
print('coef GyroZ-qj', np.corrcoef(df['GyroZ'],y=df['qj']))
print('coef GyroZ-qk', np.corrcoef(df['GyroZ'],y=df['qk']))
print('coef GyroX-qw', np.corrcoef(df['GyroX'],y=df['qw']))
print('coef GyroY-qw', np.corrcoef(df['GyroY'],y=df['qw']))
print('coef GyroZ-qw', np.corrcoef(df['GyroZ'],y=df['qw']))



AccX_fft=fftpack.fft(np.array(df['AccX']))
AccY_fft=fftpack.fft(np.array(df['AccY']))
AccZ_fft=fftpack.fft(np.array(df['AccZ']))
GyroX_fft=fftpack.fft(np.array(df['GyroX']))
GyroY_fft=fftpack.fft(np.array(df['GyroY']))
GyroZ_fft=fftpack.fft(np.array(df['GyroZ']))

pow_AccX=np.abs(AccX_fft)
pow_AccY=np.abs(AccY_fft)
pow_AccZ=np.abs(AccZ_fft)
pow_GyroX=np.abs(GyroX_fft)
pow_GyroY=np.abs(GyroY_fft)
pow_GyroZ=np.abs(GyroZ_fft)

AccX_freq = fftpack.fftfreq(np.array(df['AccX']).size, d=dt)
AccY_freq = fftpack.fftfreq(np.array(df['AccY']).size, d=dt)
AccZ_freq = fftpack.fftfreq(np.array(df['AccZ']).size, d=dt)
GyroX_freq = fftpack.fftfreq(np.array(df['GyroX']).size, d=dt)
GyroY_freq = fftpack.fftfreq(np.array(df['GyroY']).size, d=dt)
GyroZ_freq = fftpack.fftfreq(np.array(df['GyroZ']).size, d=dt)

plt.plot(AccX_freq, pow_AccX, label='Frequences_accX')
plt.xlabel('Freq')
plt.ylabel('Power')
plt.xlim([0.1,3])
plt.ylim([0,20000])
plt.legend()
plt.show()
plt.plot(AccY_freq, pow_AccY, label='Frequences_accY')
plt.xlabel('Freq')
plt.ylabel('Power')
plt.xlim([0.1,3])
plt.ylim([0,20000])
plt.legend()
plt.show()
plt.plot(AccZ_freq, pow_AccZ, label='Frequences_accZ')
plt.xlabel('Freq')
plt.ylabel('Power')
plt.xlim([0.1,3])
plt.ylim([0,20000])
plt.legend()
plt.show()
plt.plot(GyroX_freq, pow_GyroX, label='freq_gyroX')
plt.xlabel('Freq')
plt.ylabel('Power')
plt.xlim([0.1,3])
plt.ylim([0,20000])
plt.legend()
plt.show()
plt.plot(GyroY_freq, pow_GyroY, label='freq_gyroY')
plt.xlabel('Freq')
plt.ylabel('Power')
plt.xlim([0.1,3])
plt.ylim([0,20000])
plt.legend()
plt.show()
plt.plot(GyroZ_freq, pow_GyroZ, label='freq_gyroZ')
plt.xlabel('Freq')
plt.ylabel('Power')
plt.xlim([0.1,3])
plt.ylim([0,20000])
plt.legend()
plt.show()




pos_mask = np.where(AccX_freq > 0)
freqs = AccX_freq[pos_mask]
AccX_peak_freq = freqs[pow_AccX[pos_mask].argmax()]
pos_mask = np.where(AccY_freq > 0)
freqs = AccY_freq[pos_mask]
AccY_peak_freq = freqs[pow_AccY[pos_mask].argmax()]
pos_mask = np.where(AccZ_freq > 0)
freqs = AccZ_freq[pos_mask]
AccZ_peak_freq = freqs[pow_AccZ[pos_mask].argmax()]
pos_mask = np.where(GyroX_freq > 0)
freqs = GyroX_freq[pos_mask]
GyroX_peak_freq = freqs[pow_GyroX[pos_mask].argmax()]
pos_mask = np.where(GyroY_freq > 0)
freqs = GyroY_freq[pos_mask]
GyroY_peak_freq = freqs[pow_GyroY[pos_mask].argmax()]
pos_mask = np.where(GyroZ_freq > 0)
freqs = GyroZ_freq[pos_mask]
GyroZ_peak_freq = freqs[pow_GyroZ[pos_mask].argmax()]



high_freq_fft_AccX = AccX_fft.copy()
high_freq_fft_AccY = AccY_fft.copy()
high_freq_fft_AccZ = AccZ_fft.copy()
high_freq_fft_GyroX = GyroX_fft.copy()
high_freq_fft_GyroY = GyroY_fft.copy()
high_freq_fft_GyroZ = GyroZ_fft.copy()
#high_freq_fft_AccX[np.abs(AccX_freq) > AccX_peak_freq] = 0
#high_freq_fft_AccY[np.abs(AccY_freq) > AccY_peak_freq] = 0
#high_freq_fft_AccZ[np.abs(AccZ_freq) > AccZ_peak_freq] = 0
#high_freq_fft_GyroX[np.abs(GyroX_freq) > GyroX_peak_freq] = 0
#high_freq_fft_GyroY[np.abs(GyroY_freq) > GyroY_peak_freq] = 0
#high_freq_fft_GyroZ[np.abs(GyroZ_freq) > GyroZ_peak_freq] = 0
filtered_sig_AccX = fftpack.ifft(high_freq_fft_AccX)
filtered_sig_AccY = fftpack.ifft(high_freq_fft_AccY)
filtered_sig_AccZ = fftpack.ifft(high_freq_fft_AccZ)
filtered_sig_GyroX = fftpack.ifft(high_freq_fft_GyroX)
filtered_sig_GyroY = fftpack.ifft(high_freq_fft_GyroY)
filtered_sig_GyroZ = fftpack.ifft(high_freq_fft_GyroZ)

plt.plot(time, df['AccX'], label='Original signal AccX')
plt.plot(time, filtered_sig_AccX, linewidth=3, label='Filtered signal Acc X')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.plot(time, df['AccY'], label='Original signal AccY')
plt.plot(time, filtered_sig_AccY, linewidth=3, label='Filtered signal Acc Y')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.plot(time, df['AccZ'], label='Original signal AccZ')
plt.plot(time, filtered_sig_AccZ, linewidth=3, label='Filtered signal Acc Z')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.plot(time, df['GyroX'], label='Original signal GyroX')
plt.plot(time, filtered_sig_GyroX, linewidth=3, label='Filtered signal Gyro X')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.plot(time, df['GyroY'], label='Original signal GyroY')
plt.plot(time, filtered_sig_GyroY, linewidth=3, label='Filtered signal Gyro Y')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

plt.plot(time, df['GyroZ'], label='Original signal GyroZ')
plt.plot(time, filtered_sig_GyroZ, linewidth=3, label='Filtered signal Gyro Z')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
#        Log Mode  Log Freq   Timestamp    AccX     AccY     AccZ     GyroX  \
# 2618          5       200  1576222784 -34.404  108.824 -945.866 -2.870229
# 2619          5       200  1576222784 -24.034  107.116 -957.029 -2.961832
# 2620          5       200  1576222784 -27.877  103.212 -952.820 -2.870229
# 2621          5       200  1576222784 -33.611  108.946 -939.461 -2.748092
# 2622          5       200  1576222784 -29.768  111.386 -950.258 -2.854962
# ...         ...       ...         ...     ...      ...      ...       ...
# 12399         5       200  1576222828 -32.757  114.985 -943.243 -2.381679
# 12400         5       200  1576222828 -29.646  120.414 -943.914 -2.656489
# 12401         5       200  1576222828 -37.820  121.451 -938.851 -2.748092
# 12402         5       200  1576222828 -35.990  114.802 -923.967 -2.687023
# 12403         5       200  1576222828 -28.609  119.377 -948.855 -2.503817
#
#           GyroY     GyroZ  MagnX  MagnY  MagnZ        qw        qi        qj  \
# ...
